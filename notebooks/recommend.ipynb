# %% [markdown]
# # Churn Prevention Recommendation System
#
# Loads the trained best model and preprocessing pipeline, then for any customer predicted to churn,
# finds the **minimal actionable changes** needed to flip the prediction to "Not Churn".
#
# **Actionable features** (with logical direction):
# - **Total Spend** → increase (offer discount / promo)
# - **Contract Length** → change if it helps (Monthly → Quarterly, etc.)
# - **Payment Delay** → decrease (payment reminders / auto-pay)
# - **Support Calls** → decrease (proactive issue resolution)
# - **Usage Frequency** → increase (engagement campaigns, tutorials)
# - **Last Interaction** → decrease (proactive outreach within N days)

# %%
import joblib
import pandas as pd
import numpy as np

# Load saved artifacts
best_model = joblib.load('../models/best_model.joblib')
pipeline = joblib.load('../models/preprocessing_pipeline.joblib')
column_info = joblib.load('../models/column_info.joblib')

feature_columns = column_info['feature_columns']
best_model_name = column_info['best_model_name']

print(f"Loaded model : {best_model_name}")
print(f"Features      : {feature_columns}")
# Out:
# Loaded model : Random Forest
# Features      : ['Gender', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend', 'Last Interaction', 'AgeGroup']

# %% [markdown]
# ## Define Recommendation Engine
#
# **Strategy — Counterfactual search with greedy minimal changes:**
#
# 1. Predict the customer. If **Not Churn** → no action needed.
# 2. If **Churn** → try changing **one feature at a time** (binary search for minimum).
# 3. Pick the single-feature change that flips the prediction with the **smallest effort**.
# 4. If no single feature is sufficient, combine the **top-2**, then top-3, etc. (minimized per feature).
# 5. **6 actionable levers:** Total Spend, Payment Delay, Support Calls, Usage Frequency, Last Interaction, Contract Length.

# %%
# ---------------------------------------------------------------------------
# Thresholds & step sizes for each actionable feature
# ---------------------------------------------------------------------------
# Total Spend       — increase in steps of $50  (discount / promo)
# Payment Delay     — decrease in steps of 1 day  (payment reminders)
# Support Calls     — decrease in steps of 1 call (proactive issue resolution)
# Usage Frequency   — increase in steps of 1 session (engagement campaigns)
# Last Interaction  — decrease in steps of 1 day  (proactive outreach)
# Contract Length   — categorical: try Monthly → Quarterly → Annual (or vice versa)

NUMERIC_ACTIONS = {
    # feature name     : (direction, step_size, min_value, max_value, unit)
    'Total Spend'      : ('increase', 50,   0,  2000, '$'),
    'Payment Delay'    : ('decrease',  1,   0,    50, 'days'),
    'Support Calls'    : ('decrease',  1,   0,    15, 'calls'),
    'Usage Frequency'  : ('increase',  1,   1,    30, 'sessions/month'),
    'Last Interaction' : ('decrease',  1,   1,    30, 'days'),
}

CONTRACT_ORDER = ['Monthly', 'Quarterly', 'Annual']  # upgrade path


def predict(row_df):
    """Return (prediction, churn_probability) for a single-row DataFrame."""
    X_proc = pipeline.transform(row_df)
    pred = best_model.predict(X_proc)[0]
    proba = best_model.predict_proba(X_proc)[0][1]
    return int(pred), float(proba)


def _try_numeric_change(base_row, feature, direction, step, min_val, max_val):
    """Binary-search for the minimal numeric nudge that flips churn to not churn.
    Returns (new_value, steps_needed) or (None, None) if impossible."""
    original = base_row[feature].values[0]

    # Check if extreme value can flip at all
    extreme = max_val if direction == 'increase' else min_val
    test = base_row.copy()
    test[feature] = extreme
    pred, _ = predict(test)
    if pred == 1:
        return None, None  # even extreme value can't flip this feature alone

    # Binary search between original and extreme
    lo, hi = 0, abs(extreme - original)
    best_delta = hi

    for _ in range(60):
        mid = (lo + hi) / 2
        candidate = original + mid if direction == 'increase' else original - mid
        test = base_row.copy()
        test[feature] = candidate
        pred, _ = predict(test)
        if pred == 0:
            best_delta = mid
            hi = mid
        else:
            lo = mid
        if hi - lo < 0.5 * step:
            break

    # Round up to nearest step
    steps_needed = int(np.ceil(best_delta / step))
    if direction == 'increase':
        new_value = original + steps_needed * step
    else:
        new_value = original - steps_needed * step
    new_value = max(min_val, min(max_val, new_value))

    # Verify rounded value actually flips
    test = base_row.copy()
    test[feature] = new_value
    pred, _ = predict(test)
    if pred == 1:
        # One extra step
        new_value = new_value + step if direction == 'increase' else new_value - step
        new_value = max(min_val, min(max_val, new_value))
        test[feature] = new_value
        pred, _ = predict(test)
        if pred == 1:
            return None, None

    return new_value, steps_needed


def _try_contract_change(base_row):
    """Try all other contract lengths. Returns (new_contract, None) or (None, None)."""
    current = base_row['Contract Length'].values[0]
    if current not in CONTRACT_ORDER:
        return None, None
    idx = CONTRACT_ORDER.index(current)
    # Try upgrade first
    for new_idx in range(idx + 1, len(CONTRACT_ORDER)):
        test = base_row.copy()
        test['Contract Length'] = CONTRACT_ORDER[new_idx]
        pred, _ = predict(test)
        if pred == 0:
            return CONTRACT_ORDER[new_idx], None
    # Then try downgrade
    for new_idx in range(idx - 1, -1, -1):
        test = base_row.copy()
        test['Contract Length'] = CONTRACT_ORDER[new_idx]
        pred, _ = predict(test)
        if pred == 0:
            return CONTRACT_ORDER[new_idx], None
    return None, None


def get_single_feature_candidates(base_row):
    """Try each actionable feature alone. Return list of viable single changes."""
    candidates = []

    for feat, (direction, step, mn, mx, unit) in NUMERIC_ACTIONS.items():
        new_val, steps = _try_numeric_change(base_row, feat, direction, step, mn, mx)
        if new_val is not None:
            original = base_row[feat].values[0]
            delta = abs(new_val - original)
            candidates.append({
                'features_changed': [feat],
                'changes': {feat: {'from': original, 'to': new_val,
                                   'delta': delta, 'unit': unit,
                                   'direction': direction}},
            })

    new_contract, _ = _try_contract_change(base_row)
    if new_contract is not None:
        original = base_row['Contract Length'].values[0]
        candidates.append({
            'features_changed': ['Contract Length'],
            'changes': {'Contract Length': {'from': original, 'to': new_contract,
                                            'delta': 0, 'unit': '',
                                            'direction': 'change'}},
        })

    return candidates


def get_multi_feature_candidates(base_row):
    """Greedy combination: find minimal feature combination to flip churn."""
    from itertools import combinations

    actionable = list(NUMERIC_ACTIONS.keys()) + ['Contract Length']

    # Best single-direction target per feature (extreme value as fallback)
    partials = {}
    for feat, (direction, step, mn, mx, unit) in NUMERIC_ACTIONS.items():
        new_val, _ = _try_numeric_change(base_row, feat, direction, step, mn, mx)
        if new_val is not None:
            partials[feat] = new_val
        else:
            # Use extreme value for combination attempts
            partials[feat] = mx if direction == 'increase' else mn

    new_contract, _ = _try_contract_change(base_row)
    if new_contract is not None:
        partials['Contract Length'] = new_contract
    elif 'Contract Length' in actionable:
        current = base_row['Contract Length'].values[0]
        idx = CONTRACT_ORDER.index(current) if current in CONTRACT_ORDER else 0
        partials['Contract Length'] = CONTRACT_ORDER[(idx + 1) % len(CONTRACT_ORDER)]

    best = None
    for r in range(2, len(actionable) + 1):
        if best is not None:
            break
        for combo in combinations(actionable, r):
            test = base_row.copy()
            changes = {}
            for feat in combo:
                if feat not in partials:
                    continue
                original = test[feat].values[0]
                test[feat] = partials[feat]
                if feat == 'Contract Length':
                    changes[feat] = {'from': original, 'to': partials[feat],
                                     'delta': 0, 'unit': '', 'direction': 'change'}
                else:
                    d, s, mn, mx, unit = NUMERIC_ACTIONS[feat]
                    changes[feat] = {'from': original, 'to': partials[feat],
                                     'delta': abs(partials[feat] - original),
                                     'unit': unit, 'direction': d}

            if len(changes) < len(combo):
                continue

            pred, _ = predict(test)
            if pred == 0:
                minimized = _minimize_combo(base_row, combo, partials)
                if minimized is not None:
                    best = {'features_changed': list(combo), 'changes': minimized}
                    break
    return best


def _minimize_combo(base_row, combo, partials):
    """Given a working combo, minimize each feature's change one at a time."""
    current = base_row.copy()
    for feat in combo:
        current[feat] = partials[feat]

    changes = {}
    for feat in combo:
        if feat == 'Contract Length':
            changes[feat] = {'from': base_row[feat].values[0], 'to': partials[feat],
                             'delta': 0, 'unit': '', 'direction': 'change'}
            continue

        direction, step, mn, mx, unit = NUMERIC_ACTIONS[feat]
        original = base_row[feat].values[0]
        target = partials[feat]

        lo, hi = 0, abs(target - original)
        best_delta = hi

        for _ in range(60):
            mid = (lo + hi) / 2
            candidate = original + mid if direction == 'increase' else original - mid
            test = current.copy()
            test[feat] = candidate
            pred, _ = predict(test)
            if pred == 0:
                best_delta = mid
                hi = mid
            else:
                lo = mid
            if hi - lo < 0.5 * step:
                break

        steps_needed = int(np.ceil(best_delta / step))
        new_val = original + steps_needed * step if direction == 'increase' else original - steps_needed * step
        new_val = max(mn, min(mx, new_val))

        # Verify
        test = current.copy()
        test[feat] = new_val
        pred, _ = predict(test)
        if pred == 1:
            new_val = new_val + step if direction == 'increase' else new_val - step
            new_val = max(mn, min(mx, new_val))

        current[feat] = new_val
        changes[feat] = {'from': original, 'to': new_val,
                         'delta': abs(new_val - original), 'unit': unit,
                         'direction': direction}

    pred, _ = predict(current)
    if pred == 1:
        return None
    return changes


def recommend(customer_row: pd.DataFrame):
    """For a single-row DataFrame, return minimal actionable recommendations to prevent churn."""
    pred, proba = predict(customer_row)

    if pred == 0:
        return {
            'status': 'NO_ACTION',
            'message': 'Customer is NOT predicted to churn. No action needed.',
            'churn_probability': proba,
        }

    # Step 1: single-feature fix
    singles = get_single_feature_candidates(customer_row)
    if singles:
        best_single = min(singles, key=lambda c: sum(v['delta'] for v in c['changes'].values()))
        test = customer_row.copy()
        for feat, chg in best_single['changes'].items():
            test[feat] = chg['to']
        new_pred, new_proba = predict(test)
        return {
            'status': 'SINGLE_CHANGE',
            'message': 'One change is enough to prevent churn.',
            'original_churn_prob': proba,
            'new_churn_prob': new_proba,
            'recommendations': best_single['changes'],
        }

    # Step 2: multi-feature combination
    multi = get_multi_feature_candidates(customer_row)
    if multi:
        test = customer_row.copy()
        for feat, chg in multi['changes'].items():
            test[feat] = chg['to']
        new_pred, new_proba = predict(test)
        return {
            'status': 'MULTI_CHANGE',
            'message': f"Combined changes across {len(multi['features_changed'])} features needed.",
            'original_churn_prob': proba,
            'new_churn_prob': new_proba,
            'recommendations': multi['changes'],
        }

    return {
        'status': 'HIGH_RISK',
        'message': 'Cannot prevent churn — escalate to retention team.',
        'churn_probability': proba,
    }


print("Recommendation engine ready.")
# Out:
# Recommendation engine ready.

# %% [markdown]
# ## Pretty-Print Helper

# %%
def print_recommendation(result, customer_label="Customer"):
    """Nicely format the recommendation output."""
    print(f"\n{'='*65}")
    print(f"  Recommendation Report — {customer_label}")
    print(f"{'='*65}")

    if result['status'] == 'NO_ACTION':
        print(f"  ✅ {result['message']}")
        print(f"  Churn probability: {result['churn_probability']:.2%}")
        print(f"{'='*65}\n")
        return

    if result['status'] == 'HIGH_RISK':
        print(f"  🚨 {result['message']}")
        print(f"  Churn probability: {result['churn_probability']:.2%}")
        print(f"{'='*65}\n")
        return

    print(f"  ⚠️  Status: {'Single change' if result['status'] == 'SINGLE_CHANGE' else 'Multiple changes'}")
    print(f"  Churn prob BEFORE: {result['original_churn_prob']:.2%}")
    print(f"  Churn prob AFTER : {result['new_churn_prob']:.2%}")
    print(f"{'-'*65}")
    print(f"  Actionable Recommendations:")
    print(f"{'-'*65}")

    for feat, chg in result['recommendations'].items():
        if feat == 'Contract Length':
            print(f"  📋 Contract Length  : switch from '{chg['from']}' → '{chg['to']}'")
        elif feat == 'Total Spend':
            discount = chg['to'] - chg['from']
            print(f"  💰 Total Spend      : ${chg['from']:.0f} → ${chg['to']:.0f}"
                  f"  (offer ≥${discount:.0f} discount/promo)")
        elif feat == 'Payment Delay':
            print(f"  📅 Payment Delay    : {chg['from']:.0f} → {chg['to']:.0f} days"
                  f"  (reduce by {chg['delta']:.0f} days via payment reminders)")
        elif feat == 'Support Calls':
            print(f"  📞 Support Calls    : {chg['from']:.0f} → {chg['to']:.0f} calls"
                  f"  (resolve {chg['delta']:.0f} fewer escalations proactively)")
        elif feat == 'Usage Frequency':
            increase = chg['to'] - chg['from']
            print(f"  📈 Usage Frequency  : {chg['from']:.0f} → {chg['to']:.0f} sessions/month"
                  f"  (boost engagement by +{increase:.0f} via campaigns/tutorials)")
        elif feat == 'Last Interaction':
            print(f"  📬 Last Interaction : {chg['from']:.0f} → {chg['to']:.0f} days"
                  f"  (reach out within {chg['to']:.0f} days)")

    print(f"{'='*65}\n")


print("Display helper loaded.")
# Out:
# Display helper loaded.

# %% [markdown]
# ## Test: Single Customer Example
#
# Use the same custom input from the experiment notebook to verify the recommendation engine.

# %%
# Example customer (from experiment notebook)
# Columns: Gender, Tenure, Usage Frequency, Support Calls, Payment Delay,
#           Subscription Type, Contract Length, Total Spend, Last Interaction, AgeGroup
custom_values = ['Female', 27, 6, 4, 11, 'Premium', 'Quarterly', 933, 24, 'Adult']
customer = pd.DataFrame([custom_values], columns=feature_columns)

print("Customer profile:")
print(customer.to_string(index=False))

pred, proba = predict(customer)
print(f"\nPrediction: {'Churn' if pred == 1 else 'Not Churn'}  (churn prob: {proba:.2%})")

result = recommend(customer)
print_recommendation(result, "Example Customer")
# Out:
# Customer profile:
# Gender  Tenure  Usage Frequency  Support Calls  Payment Delay Subscription Type Contract Length  Total Spend  Last Interaction AgeGroup
# Female      27                6              4             11             Basic       Quarterly          933                24    Adult
#
# Prediction: Churn  (churn prob: 97.00%)
#
# =================================================================
#   Recommendation Report — Example Customer
# =================================================================
#   ⚠️  Status: Single change
#   Churn prob BEFORE: 97.00%
#   Churn prob AFTER : 9.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📬 Last Interaction : 24 → 15 days  (reach out within 15 days)
# =================================================================

# %% [markdown]
# ## Batch Recommendations — Run on Training Data
#
# Load the full dataset, predict churn for every customer, and generate recommendations for all predicted churners.

# %%
# Load and prepare data (same preprocessing as experiment notebook)
df = pd.read_csv('../data/customer_churn_dataset-training-master.csv')
df = df.dropna()
df = df.drop('CustomerID', axis=1)

bins = [15, 25, 35, 45, 66]
labels = ['Child', 'Youth', 'Adult', 'Senior']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False, include_lowest=True)

X = df.drop(['Churn', 'Age'], axis=1)
y = df['Churn'].astype(int)

# Predict on all rows
X_proc = pipeline.transform(X)
preds = best_model.predict(X_proc)
probas = best_model.predict_proba(X_proc)[:, 1]

churn_mask = preds == 1
print(f"Total customers  : {len(X)}")
print(f"Predicted churn  : {churn_mask.sum()}")
print(f"Predicted retain : {(~churn_mask).sum()}")
# Out:
# Total customers  : 440832
# Predicted churn  : 248528
# Predicted retain : 192304

# %%
# Generate recommendations for a sample of churners (first 10 for speed)
churn_indices = X.index[churn_mask]
sample_size = min(10, len(churn_indices))
sample_idx = churn_indices[:sample_size]

for i, idx in enumerate(sample_idx):
    row = X.iloc[[X.index.get_loc(idx)]].reset_index(drop=True)
    result = recommend(row)
    print_recommendation(result, f"Customer #{idx}")
# Out:
# =================================================================
#   Recommendation Report — Customer #0
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 2.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📞 Support Calls    : 5 → 3 calls  (resolve 2 fewer escalations proactively)
#   📬 Last Interaction : 17 → 15 days  (reach out within 15 days)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #1
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 3.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📞 Support Calls    : 10 → 4 calls  (resolve 6 fewer escalations proactively)
#   📋 Contract Length  : switch from 'Monthly' → 'Quarterly'
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #2
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 41.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   💰 Total Spend      : $185 → $535  (offer ≥$350 discount/promo)
#   📞 Support Calls    : 6 → 5 calls  (resolve 1 fewer escalations proactively)
#   📈 Usage Frequency  : 4 → 12 sessions/month  (boost engagement by +8 via campaigns/tutorials)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #3
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 34.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   💰 Total Spend      : $396 → $546  (offer ≥$150 discount/promo)
#   📞 Support Calls    : 7 → 5 calls  (resolve 2 fewer escalations proactively)
#   📋 Contract Length  : switch from 'Monthly' → 'Quarterly'
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #4
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 0.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📞 Support Calls    : 5 → 2 calls  (resolve 3 fewer escalations proactively)
#   📋 Contract Length  : switch from 'Monthly' → 'Quarterly'
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #5
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 21.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   💰 Total Spend      : $129 → $529  (offer ≥$400 discount/promo)
#   📅 Payment Delay    : 26 → 20 days  (reduce by 6 days via payment reminders)
#   📞 Support Calls    : 9 → 4 calls  (resolve 5 fewer escalations proactively)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #6
# =================================================================
#   ⚠️  Status: Single change
#   Churn prob BEFORE: 99.00%
#   Churn prob AFTER : 16.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📬 Last Interaction : 24 → 15 days  (reach out within 15 days)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #7
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 28.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   💰 Total Spend      : $445 → $545  (offer ≥$100 discount/promo)
#   📬 Last Interaction : 30 → 15 days  (reach out within 15 days)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #8
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 47.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   📞 Support Calls    : 7 → 4 calls  (resolve 3 fewer escalations proactively)
#   📈 Usage Frequency  : 5 → 6 sessions/month  (boost engagement by +1 via campaigns/tutorials)
# =================================================================
#
#
# =================================================================
#   Recommendation Report — Customer #9
# =================================================================
#   ⚠️  Status: Multiple changes
#   Churn prob BEFORE: 100.00%
#   Churn prob AFTER : 14.00%
# -----------------------------------------------------------------
#   Actionable Recommendations:
# -----------------------------------------------------------------
#   💰 Total Spend      : $415 → $515  (offer ≥$100 discount/promo)
#   📬 Last Interaction : 29 → 15 days  (reach out within 15 days)
# =================================================================

# %% [markdown]
# ## Summary Statistics — Recommendation Distribution

# %%
import matplotlib.pyplot as plt

# Run recommendations on ALL predicted churners (may take a moment)
all_results = []
for idx in churn_indices:
    row = X.iloc[[X.index.get_loc(idx)]].reset_index(drop=True)
    result = recommend(row)
    result['customer_idx'] = idx
    all_results.append(result)

# Count statuses
statuses = pd.Series([r['status'] for r in all_results]).value_counts()
print("Recommendation status breakdown:")
print(statuses)
print()

# Among actionable results, count which features are recommended
feature_counts = {}
for r in all_results:
    if 'recommendations' in r:
        for feat in r['recommendations']:
            feature_counts[feat] = feature_counts.get(feat, 0) + 1

if feature_counts:
    feat_df = pd.DataFrame(list(feature_counts.items()), columns=['Feature', 'Count'])
    feat_df = feat_df.sort_values('Count', ascending=False)

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Status pie
    axes[0].pie(statuses.values, labels=statuses.index, autopct='%1.1f%%',
                colors=['#2ecc71', '#e67e22', '#e74c3c'])
    axes[0].set_title('Recommendation Status Distribution')

    # Feature bar
    axes[1].barh(feat_df['Feature'], feat_df['Count'], color='#3498db')
    axes[1].set_xlabel('Times Recommended')
    axes[1].set_title('Most Frequently Recommended Features')

    plt.tight_layout()
    plt.show()

    print("\nFeature recommendation frequency:")
    print(feat_df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 for idx in churn_indices:
#       6     row = X.iloc[[X.index.get_loc(idx)]].reset_index(drop=True)
# ----> 7     result = recommend(row)
#       8     result['customer_idx'] = idx
#       9     all_results.append(result)
#
# Cell In[2], line 315, in recommend(customer_row)
#     306     return {
#     307         'status': 'SINGLE_CHANGE',
#     308         'message': 'One change is enough to prevent churn.',
#    (...)    311         'recommendations': best_single['changes'],
#     312     }
#     314 # --- Step 2: try multi-feature combinations ---
# --> 315 multi = get_multi_feature_candidates(customer_row)
#     316 if multi:
#     317     test = customer_row.copy()
#
# Cell In[2], line 159, in get_multi_feature_candidates(base_row)
#     156 partials = {}
#     158 for feat, (direction, step, mn, mx, unit) in NUMERIC_ACTIONS.items():
# --> 159     new_val, _ = _try_numeric_change(base_row, feat, direction, step, mn, mx)
#     160     if new_val is not None:
#     161         partials[feat] = new_val
#
# Cell In[2], line 40, in _try_numeric_change(base_row, feature, direction, step, min_val, max_val)
#      38 test = base_row.copy()
#      39 test[feature] = extreme
# ---> 40 pred, _ = predict(test)
#      41 if pred == 1:
#      42     return None, None  # even extreme change can't flip
#
# Cell In[2], line 21, in predict(row_df)
#      19 def predict(row_df):
#      20     """Return (prediction, churn_probability) for a single-row DataFrame."""
# ---> 21     X_proc = pipeline.transform(row_df)
#      22     pred = best_model.predict(X_proc)[0]
#      23     proba = best_model.predict_proba(X_proc)[0][1]
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\pipeline.py:1043, in Pipeline.transform(self, X, **params)
#    1041 Xt = X
#    1042 for _, name, transform in self._iter():
# -> 1043     Xt = transform.transform(Xt, **routed_params[name].transform)
#    1044 return Xt
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\compose\_column_transformer.py:1099, in ColumnTransformer.transform(self, X, **params)
#    1096 else:
#    1097     routed_params = self._get_empty_routing()
# -> 1099 Xs = self._call_func_on_transformers(
#    1100     X,
#    1101     None,
#    1102     _transform_one,
#    1103     column_as_labels=fit_dataframe_and_transform_dataframe,
#    1104     routed_params=routed_params,
#    1105 )
#    1106 self._validate_output(Xs)
#    1108 if not Xs:
#    1109     # All transformers are None
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\compose\_column_transformer.py:893, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     888         else:  # func is _transform_one
#     889             extra_args = {}
#     890         jobs.append(
#     891             delayed(func)(
#     892                 transformer=clone(trans) if not fitted else trans,
# --> 893                 X=_safe_indexing(X, columns, axis=1),
#     894                 y=y,
#     895                 weight=weight,
#     896                 **extra_args,
#     897                 params=routed_params[name],
#     898             )
#     899         )
#     901     return Parallel(n_jobs=self.n_jobs)(jobs)
#     903 except ValueError as e:
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\utils\_indexing.py:357, in _safe_indexing(X, indices, axis)
#     348     raise ValueError(
#     349         "Specifying the columns using strings is only supported for dataframes."
#     350     )
#     352 if hasattr(X, "iloc"):
#     353     # TODO: we should probably use is_pandas_df_or_series(X) instead but:
#     354     # 1) Currently, it (probably) works for dataframes compliant to pandas' API.
#     355     # 2) Updating would require updating some tests such as
#     356     #    test_train_test_split_mock_pandas.
# --> 357     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     358 elif is_polars_df_or_series(X):
#     359     return _polars_indexing(X, indices, indices_dtype, axis=axis)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\sklearn\utils\_indexing.py:78, in _pandas_indexing(X, key, key_dtype, axis)
#      75 else:
#      76     # check whether we should index with loc or iloc
#      77     indexer = X.iloc if key_dtype == "int" else X.loc
# ---> 78     return indexer[:, key] if axis else indexer[key]
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1386, in _LocIndexer._getitem_tuple(self, tup)
#    1384 with suppress(IndexingError):
#    1385     tup = self._expand_ellipsis(tup)
# -> 1386     return self._getitem_lowerdim(tup)
#    1388 # no multi-index, so validate all of the indexers
#    1389 tup = self._validate_tuple_indexer(tup)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1093, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1089 for i, key in zip(range(len(tup) - 1, -1, -1), reversed(tup), strict=True):
#    1090     if is_label_like(key) or is_list_like(key):
#    1091         # We don't need to check for tuples here because those are
#    1092         #  caught by the _is_nested_tuple_indexer check above.
# -> 1093         section = self._getitem_axis(key, axis=i)
#    1095         # We should never have a scalar section here, because
#    1096         #  _getitem_lowerdim is only called after a check for
#    1097         #  is_scalar_access, which that would be.
#    1098         if section.ndim == self.ndim:
#    1099             # we're in the middle of slicing through a MultiIndex
#    1100             # revise the key wrt to `section` by inserting an _NS
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexes\base.py:6297, in Index._get_indexer_strict(self, key, axis_name)
#    6294     keyarr = com.asarray_tuplesafe(keyarr)
#    6296 if self._index_as_unique:
# -> 6297     indexer = self.get_indexer_for(keyarr)
#    6298     keyarr = self.reindex(keyarr)[0]
#    6299 else:
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexes\base.py:6284, in Index.get_indexer_for(self, target)
#    6254 """
#    6255 Guaranteed return of an indexer even when non-unique.
#    6256
#    (...)   6281 array([0, 2])
#    6282 """
#    6283 if self._index_as_unique:
# -> 6284     return self.get_indexer(target)
#    6285 indexer, _ = self.get_indexer_non_unique(target)
#    6286 return indexer
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexes\base.py:3796, in Index.get_indexer(self, target, method, limit, tolerance)
#    3791     target = target.astype(dtype, copy=False)
#    3792     return this._get_indexer(
#    3793         target, method=method, limit=limit, tolerance=tolerance
#    3794     )
# -> 3796 return self._get_indexer(target, method, limit, tolerance)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexes\base.py:3821, in Index._get_indexer(self, target, method, limit, tolerance)
#    3817         tgt_values = engine._extract_level_codes(  # type: ignore[union-attr]
#    3818             target
#    3819         )
#    3820     else:
# -> 3821         tgt_values = target._get_engine_target()
#    3823     indexer = self._engine.get_indexer(tgt_values)
#    3825 return ensure_platform_int(indexer)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\indexes\base.py:5158, in Index._get_engine_target(self)
#    5145         return vals._ndarray.view("i8")
#    5146 if (
#    5147     type(self) is Index
#    5148     and isinstance(self._values, ExtensionArray)
#    (...)   5156 ):
#    5157     # TODO(ExtensionIndex): remove special-case, just use self._values
# -> 5158     return self._values.astype(object)
#    5159 return vals
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\arrays\string_arrow.py:336, in ArrowStringArray.astype(self, dtype, copy)
#     333 elif isinstance(dtype, np.dtype) and np.issubdtype(dtype, np.floating):
#     334     return self.to_numpy(dtype=dtype, na_value=np.nan)
# --> 336 return super().astype(dtype, copy=copy)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\arrays\base.py:883, in ExtensionArray.astype(self, dtype, copy)
#     881     return np.asarray(self, dtype=dtype)
#     882 else:
# --> 883     return np.array(self, dtype=dtype, copy=copy)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\arrays\arrow\array.py:864, in ArrowExtensionArray.__array__(self, dtype, copy)
#     860 elif copy is None:
#     861     # `to_numpy(copy=False)` has the meaning of NumPy `copy=None`.
#     862     copy = False
# --> 864 return self.to_numpy(dtype=dtype, copy=copy)
#
# File d:\Projects\Retain_engine_churn\env\Lib\site-packages\pandas\core\arrays\arrow\array.py:1715, in ArrowExtensionArray.to_numpy(self, dtype, copy, na_value)
#    1703     result = np.full(len(data), fill_value=na_value, dtype=dtype)
#    1704 elif not data._hasna or (
#    1705     pa.types.is_floating(pa_type)
#    1706     and (
#    (...)   1713     )
#    1714 ):
# -> 1715     result = data._pa_array.to_numpy()
#    1716     if dtype is not None:
#    1717         result = result.astype(dtype, copy=False)
#
# KeyboardInterrupt:
